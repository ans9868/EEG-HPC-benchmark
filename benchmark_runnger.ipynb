# %%
# !which python
# !which pip
# Out:
# /ext3/pyspark/bin/python
# /ext3/pyspark/bin/pip

# %%
# !pip install --user psutil numpy

# %%
# !pip install --user  numpy matplotlib scipy numba scikit-learn mne PyWavelets pandas mne-features pyyaml
# Out:
# ...
#   Using cached numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
# ...
#   Using cached matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
# ...
#   Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# ...
#   Using cached zipp-3.20.2-py3-none-any.whl (9.2 kB)
# ...
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/home/ans9868/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# %%time
# !python mne_benchmark_runner.py
# Out:
# Config not found in feature_extraction.py
# start
# load_epochs, first subject path:  sub-001
# Processing subject sub-001
# processSub sub-001
# processSub: derivatives True
# processSub: windowLength 3
# processSub: windowLength 0.3
# subPath sub-001
# subPath data_path /home/ans9868/EEG-HPC-benchmark
# Derivatives: True
# Derivatives from config: True
# Path handed: /home/ans9868/EEG-HPC-benchmark/ds004504/derivatives/sub-001/eeg/sub-001_task-eyesclosed_eeg.set
# /home/ans9868/EEG-HPC-benchmark/src/preprocess_sets.py:169: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   epochs_data = epochs.get_data()
# Processing subject sub-002
# processSub sub-002
# processSub: derivatives True
# processSub: windowLength 3
# processSub: windowLength 0.3
# subPath sub-002
# subPath data_path /home/ans9868/EEG-HPC-benchmark
# Derivatives: True
# Derivatives from config: True
# ...

# %%
# Pyspark

# %%
# !sbatch --account=pr_130_general startPySparkWorkers.sh #THIS MUST BE RUN IN THE TERMINAL (i think homedirectory of the project is best place to run this)
# Out:
# /bin/bash: sbatch: command not found

# %%
# !lsof -i :13049

# %%
# %%time
# !python benchmark_runner.py
# Out:
# start
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/ext3/spark-3.1.2-bin-hadoop3.2/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 25/05/04 19:41:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# New Spark session created successfully
# === Spark Configuration & Runtime info ===
# ...
